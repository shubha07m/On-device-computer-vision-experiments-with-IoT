# %%
from ultralytics import YOLO
from IPython.display import Image

# %% [markdown]
# ### Loading only the YOLO Phantom architecture ###

# %%
model = YOLO('yolo_phantom.yaml')
print(model)
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
# ...

# %% [markdown]
# ### Inference with YOLO Phantom trained weight ###

# %%
# Load a pretrained YOLO Phantom model
model = YOLO('yolophantom.pt')

result = model.predict('thermal_image.jpg', conf=0.5,save=True)
# Out:
# image 1/1 /Users/nemo/Desktop/On-device-computer-vision-experiments-with-IoT/yolo_phantom/thermal_image.jpg: 512x640 4 persons, 5 cars, 1 street sign, 61.6ms
# Speed: 1.3ms preprocess, 61.6ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
# Results saved to /opt/homebrew/runs/detect/predict

# %%
Image('thermal_predicted_image.jpg')

# %%
result = model.predict('rgb_image.jpg', conf=0.5,save=True)
# Out:
# image 1/1 /Users/nemo/Desktop/On-device-computer-vision-experiments-with-IoT/yolo_phantom/rgb_image.jpg: 480x640 2 persons, 12 cars, 3 street signs, 126.4ms
# Speed: 23.6ms preprocess, 126.4ms inference, 14.1ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to /opt/homebrew/runs/detect/predict

# %%
Image('rgb_predicted_image.jpg')
